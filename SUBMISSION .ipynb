# %%
import pandas as pd
from datetime import timedelta

# %%
#Final Dataset of all articles about companies (without duplicates)

all_articles = pd.read_csv("FINAL_DATASET_FIX.csv", index_col=0)
all_articles
# Out:
#              GOID                                              Title  \
# 0      1015228345  Arts &amp; Entertainment -- Speakeasy: Harris ...
# 1      1015229896                      Google's Mobile Balancing Act
# 2      1015229900         Global Finance: MetLife to Revamp Strategy
# 3      1015229902  Best Buy's Profit Drops 25% --- Interim Chief ...
# 4      1015229905                   Inside Fumbled Facebook Offering
# ...           ...                                                ...
# 95942   929136592         Global Finance: Jefferies Net Declines 12%
# 95943   929136594  Stock Markets: Seeking Apple Hints In Microsof...
# 95944   929136971  Goldman Sachs and Fairly Assessing Investment ...
# 95945   929156342  Corporate News: Apple Fans Rush Stores for New...
# 95946   929156345  Goldman Reviewing Policies On Its Deal Makers'...
#
#              Date                                              words  \
# 0      2012-05-23  ['"Smurfs" movies seat head Broadway\'s table....
# 1      2012-05-23  ['Google Inc. begins delicate balancing act wo...
# 2      2012-05-23                                                NaN
# 3      2012-05-23  ["Best Buy Co.'s quarterly profit dropped 25% ...
# 4      2012-05-23                                                NaN
# ...           ...                                                ...
# 95942  2012-03-21                                                NaN
# 95943  2012-03-21                                                NaN
# 95944  2012-03-21                                                NaN
# 95945  2012-03-17                                                NaN
# 95946  2012-03-17                                                NaN
#
#        Titlebased  Textbased        company_in_title  \
# 0             NaN        1.0              ['Harris']
# 1             NaN        1.0              ['Google']
# 2             NaN        NaN             ['MetLife']
# 3             NaN        1.0            ['Best Buy']
# 4             NaN        NaN            ['Facebook']
# ...           ...        ...                     ...
# 95942         NaN        NaN           ['Jefferies']
# 95943         NaN        NaN  ['Apple', 'Microsoft']
# 95944         NaN        NaN             ['Goldman']
# 95945         NaN        NaN               ['Apple']
# 95946         NaN        NaN             ['Goldman']
#
#                        company_in_text scandal_in_title  \
# 0                    ['CBS', 'Harris']              NaN
# 1      ['Motorola', 'Google', 'Apple']              NaN
# 2                                  NaN              NaN
# 3                         ['Best Buy']              NaN
# 4                                  NaN              NaN
# ...                                ...              ...
# 95942                              NaN              NaN
# 95943                              NaN              NaN
# 95944                              NaN              NaN
# 95945                              NaN              NaN
# 95946                              NaN              NaN
#
#                       scandal_in_text  GPT scandals_manual scandals_all
# 0                       ['insecur__']  NaN             NaN          NaN
# 1      ['discriminat__', 'antitrust']  NaN             NaN          NaN
# 2                                 NaN  NaN             NaN          NaN
# 3                  ['inappropriat__']  NaN             NaN          NaN
# 4                                 NaN  NaN             NaN          NaN
# ...                               ...  ...             ...          ...
# 95942                             NaN  NaN             NaN          NaN
# 95943                             NaN  NaN             NaN          NaN
# 95944                             NaN  NaN             NaN          NaN
# 95945                             NaN  NaN             NaN          NaN
# 95946                             NaN  NaN             NaN          NaN
#
# [95947 rows x 13 columns]

# %%
#Articles which mention a scandal in the title of the article 
scandal_title = all_articles[all_articles["Titlebased"]==1.0]
scandal_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2670 entries, 103 to 95915
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GOID              2670 non-null   int64
#  1   Title             2670 non-null   object
#  2   Date              2670 non-null   object
#  3   words             2670 non-null   object
#  4   Titlebased        2670 non-null   float64
#  5   Textbased         2436 non-null   float64
#  6   company_in_title  2670 non-null   object
#  7   company_in_text   2629 non-null   object
#  8   scandal_in_title  2670 non-null   object
#  9   scandal_in_text   2444 non-null   object
#  10  GPT               5 non-null      object
#  11  scandals_manual   570 non-null    object
#  12  scandals_all      5 non-null      object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 292.0+ KB

# %%
scandal_title.to_csv("scandal_in_title.csv")

# %%
#Articles which mention a scandal in the text of the article 
scandal_text = all_articles[all_articles["Textbased"]==1.0]
scandal_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18704 entries, 0 to 95926
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GOID              18704 non-null  int64
#  1   Title             18704 non-null  object
#  2   Date              18704 non-null  object
#  3   words             18704 non-null  object
#  4   Titlebased        2436 non-null   float64
#  5   Textbased         18704 non-null  float64
#  6   company_in_title  18704 non-null  object
#  7   company_in_text   18699 non-null  object
#  8   scandal_in_title  2436 non-null   object
#  9   scandal_in_text   18704 non-null  object
#  10  GPT               14 non-null     object
#  11  scandals_manual   524 non-null    object
#  12  scandals_all      8 non-null      object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.0+ MB

# %%
scandal_text.to_csv("scandal_in_text.csv")

# %%
#Articles which mention a scandal in the title AND text of the article (not used in the reseearch)
scandal_title_text = scandal_title[scandal_title["Textbased"]==1.0]
scandal_title_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2436 entries, 103 to 95915
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GOID              2436 non-null   int64
#  1   Title             2436 non-null   object
#  2   Date              2436 non-null   object
#  3   words             2436 non-null   object
#  4   Titlebased        2436 non-null   float64
#  5   Textbased         2436 non-null   float64
#  6   company_in_title  2436 non-null   object
#  7   company_in_text   2435 non-null   object
#  8   scandal_in_title  2436 non-null   object
#  9   scandal_in_text   2436 non-null   object
#  10  GPT               4 non-null      object
#  11  scandals_manual   524 non-null    object
#  12  scandals_all      4 non-null      object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 266.4+ KB

# %% [markdown]
# # SEVERITY SCORE CREATION

# %% [markdown]
# ## Severity Score for the Title Dataset

# %%
title_scandal = pd.read_csv("scandal_in_title.csv", index_col=0)
title_scandal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2670 entries, 103 to 95915
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GOID              2670 non-null   int64
#  1   Title             2670 non-null   object
#  2   Date              2670 non-null   object
#  3   words             2670 non-null   object
#  4   Titlebased        2670 non-null   float64
#  5   Textbased         2436 non-null   float64
#  6   company_in_title  2670 non-null   object
#  7   company_in_text   2629 non-null   object
#  8   scandal_in_title  2670 non-null   object
#  9   scandal_in_text   2444 non-null   object
#  10  GPT               5 non-null      object
#  11  scandals_manual   570 non-null    object
#  12  scandals_all      5 non-null      object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 292.0+ KB

# %%
# Convert date column to a date
title_scandal['Date'] = pd.to_datetime(title_scandal['Date'])

# %%
# Function to count additional articles in the following 14 days
def count_additional_articles(row, data):
    company = row['company_in_title']
    start_date = row['Date']
    end_date = start_date + timedelta(days=14)
    
    # Filter for articles about the same company within the next month
    mask = (title_scandal['company_in_title'] == company) & (title_scandal['Date'] > start_date) & (title_scandal['Date'] <= end_date)
    return title_scandal[mask].shape[0]

# %%
# Calculate severity scores for each articles
title_scandal['severity_score'] = title_scandal.apply(lambda row: count_additional_articles(row, title_scandal), axis=1)

# %%
#Find most severe articles
title_scandal[title_scandal['severity_score'] > 5].sort_values(by='Date')
# Out:
#             GOID                                              Title  \
# 33860  398704830     Microsoft Probes Leak Of a New Windows Version
# 33965  398692173  Microsoft's Talks With U.S. Accelerate --- Gul...
# 33475  398694895  Options Report: Microsoft Call Options Are Bou...
# 34816  398716061  Microsoft Antitrust Ruling Is Expected to Be D...
# 42360  398786261  Microsoft Settlement Efforts Collapse --- Soft...
# 41351  398780494  Microsoft Reaches Tentative Antitrust Pact ---...
#
#             Date                                              words  \
# 33860 2000-03-22  ['REDMOND, Wash. -- Microsoft Corp. investigat...
# 33965 2000-03-23  ['WASHINGTON -- Settlement talks Microsoft Cor...
# 33475 2000-03-24  ['NEW YORK -- Microsoft Corp. thundered option...
# 34816 2000-03-29  ['WASHINGTON -- Settlement talks Microsoft Cor...
# 42360 2000-04-03  ['WASHINGTON -- Settlement efforts Microsoft C...
# 41351 2001-11-01  ['WASHINGTON -- Microsoft Corp. reached tentat...
#
#        Titlebased  Textbased company_in_title  \
# 33860         1.0        1.0    ['Microsoft']
# 33965         1.0        1.0    ['Microsoft']
# 33475         1.0        1.0    ['Microsoft']
# 34816         1.0        1.0    ['Microsoft']
# 42360         1.0        1.0    ['Microsoft']
# 41351         1.0        1.0    ['Microsoft']
#
#                                     company_in_text  \
# 33860                                 ['Microsoft']
# 33965                                 ['Microsoft']
# 33475                       ['Microsoft', 'Unocal']
# 34816                                 ['Microsoft']
# 42360  ['Sun Microsystems', 'Microsoft', 'Goldman']
# 41351                                 ['Microsoft']
#
#                 scandal_in_title  \
# 33860                 ['leak__']
# 33965             ['settlement']
# 33475   ['lawsuit', 'antitrust']
# 34816              ['antitrust']
# 42360             ['settlement']
# 41351  ['monopoly', 'antitrust']
#
#                                          scandal_in_text  GPT scandals_manual  \
# 33860                                         ['leak__']  NaN             NaN
# 33965                         ['violat__', 'settlement']  NaN               Y
# 33475             ['lawsuit', 'antitrust', 'settlement']  NaN             NaN
# 34816                        ['illegal__', 'settlement']  NaN               Y
# 42360           ['antitrust', 'settlement', 'litigat__']  NaN             NaN
# 41351  ['monopoly', 'antitrust', 'settlement', 'litig...  NaN               Y
#
#       scandals_all  severity_score
# 33860          NaN              10
# 33965          NaN               9
# 33475          NaN               8
# 34816          NaN               7
# 42360          NaN               6
# 41351          NaN               6

# %%
title_scandal.to_csv("title_scandal_severity.csv")

# %% [markdown]
# ## Severity Score for Text Dataset

# %%
text_scandal = pd.read_csv("scandal_in_text.csv", index_col=0)
text_scandal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18704 entries, 0 to 95926
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GOID              18704 non-null  int64
#  1   Title             18704 non-null  object
#  2   Date              18704 non-null  object
#  3   words             18704 non-null  object
#  4   Titlebased        2436 non-null   float64
#  5   Textbased         18704 non-null  float64
#  6   company_in_title  18704 non-null  object
#  7   company_in_text   18699 non-null  object
#  8   scandal_in_title  2436 non-null   object
#  9   scandal_in_text   18704 non-null  object
#  10  GPT               14 non-null     object
#  11  scandals_manual   524 non-null    object
#  12  scandals_all      8 non-null      object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.0+ MB

# %%
# Ensure the date columns are in datetime format
text_scandal['Date'] = pd.to_datetime(text_scandal['Date'])
title_scandal['Date'] = pd.to_datetime(title_scandal['Date'])

# Function to count additional articles in the following 14 days
def count_additional_articles(row, text_scandal):
    company = row['company_in_text']
    start_date = row['Date']
    end_date = start_date + timedelta(days=14)
    
    # Filter for articles about the same company within the next week
    mask = (text_scandal['company_in_text'] == company) & (text_scandal['Date'] > start_date) & (text_scandal['Date'] <= end_date)
    return text_scandal[mask].shape[0]

# %%
# Apply the function to the scandal articles DataFrame to calculate severity scores
title_scandal['severity_score'] = title_scandal.apply(lambda row: count_additional_articles(row, text_scandal), axis=1)

# %%
text_based_scandal = title_scandal

# %%
text_based_scandal[text_based_scandal['severity_score'] > 10].sort_values(by='Date')
# Out:
#             GOID                                              Title  \
# 33860  398704830     Microsoft Probes Leak Of a New Windows Version
# 33965  398692173  Microsoft's Talks With U.S. Accelerate --- Gul...
# 56502  398896501  A Scandal Centerpiece: Enron's Political Conne...
# 67768  398957408  Andersen Knew of Enron Woes a Year Ago --- Whi...
# 39773  398787425  Staff Saw Document Shredding at Enron --- Thre...
# 43283  398792881  Cast Prepares for Congressional Curtain to Ris...
# 40186  398766714  Andersen Knew of `Fraud' Risk at Enron --- Oct...
# 66980  398950883  Why We Now Need A National Association For Dat...
# 41992  398784763  Questioning the Books: Panel, in Enron's Wake,...
#
#             Date                                              words  \
# 33860 2000-03-22  ['REDMOND, Wash. -- Microsoft Corp. investigat...
# 33965 2000-03-23  ['WASHINGTON -- Settlement talks Microsoft Cor...
# 56502 2002-01-17  ['corporate CEOs, appropriately deferential Vi...
# 67768 2002-01-17  ["WASHINGTON -- Arthur Andersen LLP officials ...
# 39773 2002-01-22  ["Three former Enron Corp. employees say docum...
# 43283 2002-01-23  ["WASHINGTON -- Congress returns new year toda...
# 40186 2002-01-25  ['Arthur Andersen LLP analysts determined fall...
# 66980 2002-01-30  ["gnashing blades, slice tangled ribbons. get ...
# 41992 2002-02-06  ['WASHINGTON -- federal investigators Congress...
#
#        Titlebased  Textbased company_in_title company_in_text  \
# 33860         1.0        1.0    ['Microsoft']   ['Microsoft']
# 33965         1.0        1.0    ['Microsoft']   ['Microsoft']
# 56502         1.0        1.0        ['Enron']       ['Enron']
# 67768         1.0        1.0        ['Enron']       ['Enron']
# 39773         1.0        1.0        ['Enron']       ['Enron']
# 43283         1.0        1.0        ['Enron']       ['Enron']
# 40186         1.0        1.0        ['Enron']       ['Enron']
# 66980         1.0        1.0        ['Enron']       ['Enron']
# 41992         1.0        1.0        ['Enron']       ['Enron']
#
#         scandal_in_title             scandal_in_text  GPT scandals_manual  \
# 33860         ['leak__']                  ['leak__']  NaN             NaN
# 33965     ['settlement']  ['violat__', 'settlement']  NaN               Y
# 56502      ['scandal__']               ['scandal__']  NaN             NaN
# 67768  ['whistleblow__']             ['irregular__']  NaN             NaN
# 39773     ['destruct__']               ['illegal__']  NaN             NaN
# 43283      ['scandal__']               ['scandal__']  NaN             NaN
# 40186          ['fraud']     ['destruct__', 'fraud']  NaN             NaN
# 66980     ['destruct__']              ['destruct__']  NaN               Y
# 41992        ['lawsuit']               ['litigat__']  NaN             NaN
#
#       scandals_all  severity_score
# 33860          NaN              12
# 33965          NaN              12
# 56502          NaN              20
# 67768          NaN              20
# 39773          NaN              18
# 43283          NaN              20
# 40186          NaN              21
# 66980          NaN              20
# 41992          NaN              18

# %%
text_based_scandal.to_csv("text_scandal_severity.csv")

# %% [markdown]
# ## Severity Score Based on All Company Articles

# %%
# Ensure the date columns are in datetime format
all_articles['Date'] = pd.to_datetime(all_articles['Date'])
title_scandal['Date'] = pd.to_datetime(title_scandal['Date'])

# Function to count additional articles in the following 14 days
def count_additional_articles(row, text_scandal):
    company = row['company_in_title']
    start_date = row['Date']
    end_date = start_date + timedelta(days=14)
    
    # Filter for articles about the same company within the next 14 days
    mask = (all_articles['company_in_title'] == company) & (all_articles['Date'] > start_date) & (all_articles['Date'] <= end_date)
    return all_articles[mask].shape[0]

# %%
# Apply the function to the scandal articles DataFrame to calculate severity scores
title_scandal['severity_score'] = title_scandal.apply(lambda row: count_additional_articles(row, all_articles), axis=1)

# %%
all_based_scandal = title_scandal

# %%
all_based_scandal[all_based_scandal['severity_score'] > 23].sort_values(by='Date')
# Out:
#              GOID                                              Title  \
# 33860   398704830     Microsoft Probes Leak Of a New Windows Version
# 33965   398692173  Microsoft's Talks With U.S. Accelerate --- Gul...
# 33475   398694895  Options Report: Microsoft Call Options Are Bou...
# 34816   398716061  Microsoft Antitrust Ruling Is Expected to Be D...
# 42360   398786261  Microsoft Settlement Efforts Collapse --- Soft...
# 35589   398705912  A Tricky Element in the Antitrust Battle: Micr...
# 32490   398704302  For Antitrust Judge, Trust, or Lack of It, Rea...
# 54270   398869445  GE-Honeywell Deal's Problems Deepen --- Europe...
# 67768   398957408  Andersen Knew of Enron Woes a Year Ago --- Whi...
# 56502   398896501  A Scandal Centerpiece: Enron's Political Conne...
# 39773   398787425  Staff Saw Document Shredding at Enron --- Thre...
# 43283   398792881  Cast Prepares for Congressional Curtain to Ris...
# 40186   398766714  Andersen Knew of `Fraud' Risk at Enron --- Oct...
# 66980   398950883  Why We Now Need A National Association For Dat...
# 41992   398784763  Questioning the Books: Panel, in Enron's Wake,...
# 60060   398913602                    Enron Didn't Corrupt Washington
# 46330   398809484  Audit Aftermath: Beset Over Enron, Andersen Fa...
# 45267   398802890  Small Investors Are Down, but Not Out --- Enro...
# 56686   398884146  Emerging Stock Markets Appear Less Risky After...
# 42583   398776073  Enron May Try for Tax-Shelter Amnesty --- IRS ...
# 67497   398965108  Questioning the Books: SEC Urges Plaintiffs Su...
# 57780   398871997  Quarterly Stock Market Review -- Essay --- Enr...
# 93919    89150159  U.S. Charges Goldman Sachs With Fraud --- SEC ...
# 88769   399133154  SEC v. Goldman Sachs: Fraud Allegations Furthe...
# 18675   231339029  SEC v. Goldman Sachs: Bank Wages Battle to Sav...
# 18674   231338951  New Goldman Shockwaves --- Firm Contends It Wa...
# 5820   1558964903             Apple: 'Targeted Attack' Led to Breach
#
#             Date                                              words  \
# 33860 2000-03-22  ['REDMOND, Wash. -- Microsoft Corp. investigat...
# 33965 2000-03-23  ['WASHINGTON -- Settlement talks Microsoft Cor...
# 33475 2000-03-24  ['NEW YORK -- Microsoft Corp. thundered option...
# 34816 2000-03-29  ['WASHINGTON -- Settlement talks Microsoft Cor...
# 42360 2000-04-03  ['WASHINGTON -- Settlement efforts Microsoft C...
# 35589 2000-04-19  ['WASHINGTON -- federal antitrust enforcers fo...
# 32490 2000-06-08  ['WASHINGTON -- start Microsoft trial, one fig...
# 54270 2001-06-12  ["BRUSSELS -- General Electric Co.'s planned a...
# 67768 2002-01-17  ["WASHINGTON -- Arthur Andersen LLP officials ...
# 56502 2002-01-17  ['corporate CEOs, appropriately deferential Vi...
# 39773 2002-01-22  ["Three former Enron Corp. employees say docum...
# 43283 2002-01-23  ["WASHINGTON -- Congress returns new year toda...
# 40186 2002-01-25  ['Arthur Andersen LLP analysts determined fall...
# 66980 2002-01-30  ["gnashing blades, slice tangled ribbons. get ...
# 41992 2002-02-06  ['WASHINGTON -- federal investigators Congress...
# 60060 2002-02-12  ['campaign-finance reform, part deux. years, S...
# 46330 2002-02-19  ["fraud dismissed. sudden bankruptcy. Investor...
# 45267 2002-02-19  ['resolve, many soldiering on, putting even mo...
# 56686 2002-02-25  ['Could emerging stock markets unexpected bene...
# 42583 2002-02-28  ['WASHINGTON -- Enron Corp., scrutiny Internal...
# 67497 2002-03-01  ['Securities Exchange Commission pushing plain...
# 57780 2002-04-01  ["SEARCH Enron Corp.'s lasting impact, editors...
# 93919 2010-04-17  ['Goldman Sachs Group Inc. -- one Wall Street ...
# 88769 2010-04-17  ["government's civil-fraud charges Goldman Sac...
# 18675 2010-04-19  ["Goldman Sachs Group Inc. mobilizing countera...
# 18674 2010-04-19  ['Goldman Sachs Group Inc. officials said knew...
# 5820  2014-09-03  ['One week Apple Inc. plans show new iPhone, c...
#
#        Titlebased  Textbased company_in_title  \
# 33860         1.0        1.0    ['Microsoft']
# 33965         1.0        1.0    ['Microsoft']
# 33475         1.0        1.0    ['Microsoft']
# 34816         1.0        1.0    ['Microsoft']
# 42360         1.0        1.0    ['Microsoft']
# 35589         1.0        1.0    ['Microsoft']
# 32490         1.0        1.0    ['Microsoft']
# 54270         1.0        1.0           ['GE']
# 67768         1.0        1.0        ['Enron']
# 56502         1.0        1.0        ['Enron']
# 39773         1.0        1.0        ['Enron']
# 43283         1.0        1.0        ['Enron']
# 40186         1.0        1.0        ['Enron']
# 66980         1.0        1.0        ['Enron']
# 41992         1.0        1.0        ['Enron']
# 60060         1.0        1.0        ['Enron']
# 46330         1.0        1.0        ['Enron']
# 45267         1.0        NaN        ['Enron']
# 56686         1.0        1.0        ['Enron']
# 42583         1.0        1.0        ['Enron']
# 67497         1.0        1.0        ['Enron']
# 57780         1.0        NaN        ['Enron']
# 93919         1.0        1.0      ['Goldman']
# 88769         1.0        1.0      ['Goldman']
# 18675         1.0        1.0      ['Goldman']
# 18674         1.0        1.0      ['Goldman']
# 5820          1.0        1.0        ['Apple']
#
#                                          company_in_text  \
# 33860                                      ['Microsoft']
# 33965                                      ['Microsoft']
# 33475                            ['Microsoft', 'Unocal']
# 34816                                      ['Microsoft']
# 42360       ['Sun Microsystems', 'Microsoft', 'Goldman']
# 35589  ['IBM', 'Sun Microsystems', 'Microsoft', 'Orac...
# 32490  ['IBM', 'Southern', 'Microsoft', 'General Moto...
# 54270  ['Honeywell International', 'General Electric'...
# 67768                                          ['Enron']
# 56502                                          ['Enron']
# 39773                                          ['Enron']
# 43283                                          ['Enron']
# 40186                                          ['Enron']
# 66980                                          ['Enron']
# 41992                                          ['Enron']
# 60060                             ['Coca-Cola', 'Enron']
# 46330                      ['AT&T', 'Southern', 'Enron']
# 45267  ['Qualcomm', 'Aflac', 'Disney', 'AMR', 'Enron'...
# 56686  ['IBM', 'Kimberly-Clark', 'Nvidia', 'Coca-Cola...
# 42583                                          ['Enron']
# 67497                                          ['Enron']
# 57780  ['Merrill Lynch', 'Enron', 'GE', 'General Elec...
# 93919  ['Goldman', 'Bear Stearns', 'Goldman', 'Merril...
# 88769  ['Chase', 'AIG', 'J.P. Morgan', 'Goldman', 'Go...
# 18675        ['Goldman', 'Goldman', 'Washington Mutual']
# 18674            ['Goldman', 'Goldman', 'Merrill Lynch']
# 5820                              ['Apple', 'Microsoft']
#
#                scandal_in_title  \
# 33860                ['leak__']
# 33965            ['settlement']
# 33475  ['lawsuit', 'antitrust']
# 34816             ['antitrust']
# 42360            ['settlement']
# 35589             ['antitrust']
# 32490             ['antitrust']
# 54270             ['antitrust']
# 67768         ['whistleblow__']
# 56502             ['scandal__']
# 39773            ['destruct__']
# 43283             ['scandal__']
# 40186                 ['fraud']
# 66980            ['destruct__']
# 41992               ['lawsuit']
# 60060             ['corrupt__']
# 46330                 ['fraud']
# 45267             ['scandal__']
# 56686             ['scandal__']
# 42583              ['penalt__']
# 67497            ['settlement']
# 57780             ['scandal__']
# 93919                 ['fraud']
# 88769                 ['fraud']
# 18675                 ['fraud']
# 18674               ['lawsuit']
# 5820               ['breach__']
#
#                                          scandal_in_text  GPT scandals_manual  \
# 33860                                         ['leak__']  NaN             NaN
# 33965                         ['violat__', 'settlement']  NaN               Y
# 33475             ['lawsuit', 'antitrust', 'settlement']  NaN             NaN
# 34816                        ['illegal__', 'settlement']  NaN               Y
# 42360           ['antitrust', 'settlement', 'litigat__']  NaN             NaN
# 35589        ['inappropriat__', 'monopoly', 'antitrust']  NaN             NaN
# 32490                          ['antitrust', 'violat__']  NaN               Y
# 54270                                      ['antitrust']  NaN             NaN
# 67768                                    ['irregular__']  NaN             NaN
# 56502                                      ['scandal__']  NaN             NaN
# 39773                                      ['illegal__']  NaN             NaN
# 43283                                      ['scandal__']  NaN             NaN
# 40186                            ['destruct__', 'fraud']  NaN             NaN
# 66980                                     ['destruct__']  NaN               Y
# 41992                                      ['litigat__']  NaN             NaN
# 60060                                      ['scandal__']  NaN             NaN
# 46330                            ['improper__', 'fraud']  NaN             NaN
# 45267                                                NaN  NaN             NaN
# 56686                                      ['scandal__']  NaN             NaN
# 42583                                       ['penalt__']  NaN             NaN
# 67497                        ['scandal__', 'settlement']  NaN             NaN
# 57780                                                NaN  NaN             NaN
# 93919                                       ['deceiv__']  NaN             NaN
# 88769                                          ['fraud']  NaN             NaN
# 18675                               ['lawsuit', 'fraud']  NaN             NaN
# 18674  ['fraud', 'settlement', 'litigat__', 'lawsuit'...  NaN             NaN
# 5820                                          ['leak__']  NaN             NaN
#
#       scandals_all  severity_score
# 33860          NaN              36
# 33965          NaN              36
# 33475          NaN              36
# 34816          NaN              34
# 42360          NaN              33
# 35589          NaN              29
# 32490          NaN              32
# 54270          NaN              24
# 67768          NaN              67
# 56502          NaN              67
# 39773          NaN              56
# 43283          NaN              56
# 40186          NaN              56
# 66980          NaN              60
# 41992          NaN              55
# 60060          NaN              40
# 46330          NaN              37
# 45267          NaN              37
# 56686          NaN              35
# 42583          NaN              28
# 67497          NaN              24
# 57780          NaN              27
# 93919          NaN              55
# 88769          NaN              55
# 18675          NaN              50
# 18674          NaN              50
# 5820           NaN              24

# %%
all_based_scandal.to_csv("all_scandal_severity.csv")

# %% [markdown]
# # Plot with Volume of Companies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
from matplotlib.ticker import FuncFormatter

# Load and sort the scandal data
all_articles = pd.read_csv('FINAL_DATASET_FIX.csv')
scandal_articles_df = scandal_articles_df.sort_values(by='Date', ascending=True)
scandal_articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2670 entries, 838 to 720
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2670 non-null   int64
#  1   GOID              2670 non-null   int64
#  2   Title             2670 non-null   object
#  3   Date              2670 non-null   object
#  4   words             2670 non-null   object
#  5   Titlebased        2670 non-null   float64
#  6   Textbased         2436 non-null   float64
#  7   company_in_title  2670 non-null   object
#  8   company_in_text   2629 non-null   object
#  9   scandal_in_title  2670 non-null   object
#  10  scandal_in_text   2444 non-null   object
#  11  GPT               5 non-null      object
#  12  scandals_manual   570 non-null    object
#  13  scandals_all      5 non-null      object
#  14  severity_score    2670 non-null   int64
# dtypes: float64(2), int64(3), object(10)
# memory usage: 333.8+ KB

# %%
# Load the stock data (Check the excel to know what is what company)
stock_data = pd.read_excel("../Stock_FINAL.xlsx", sheet_name = 1)
stock_data
# Out:
#            Date  PX_LAST  PX_VOLUME
# 0    2004-11-17   0.0380    2577215
# 1    2004-11-16   0.0360    3340257
# 2    2004-11-15   0.0295    5481734
# 3    2004-11-12   0.0400     559420
# 4    2004-11-11   0.0400     506568
# ...         ...      ...        ...
# 1724 1998-01-07  19.5000    3361600
# 1725 1998-01-06  19.3750    4071000
# 1726 1998-01-05  20.0000    1970800
# 1727 1998-01-02  20.3750    1293200
# 1728 1997-12-31  20.7813    1370200
#
# [1729 rows x 3 columns]

# %% [markdown]
# ## We plot for Apple in this case

# %% [markdown]
# ### To plot for other companies, just change the sheet number and company name in the code
# #### Check severity score of the most severe articles to check which period to plot

# %%
# Load and preprocess the title-based scandal data
title_scandal_df = pd.read_csv('title_scandal_severity.csv')
title_scandal_df['Date'] = pd.to_datetime(title_scandal_df['Date'])
title_scandal_df['company_in_title'] = title_scandal_df['company_in_title'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# Load and preprocess the text-based scandal data
text_scandal_df = pd.read_csv('text_scandal_severity.csv')
text_scandal_df['Date'] = pd.to_datetime(text_scandal_df['Date'])
text_scandal_df['company_in_text'] = text_scandal_df['company_in_text'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# Load all articles data about companies
all_articles_df = pd.read_csv('final_data_with_count_and_annotation.csv')
all_articles_df['Date'] = pd.to_datetime(all_articles_df['Date'])
all_articles_df['company_in_title'] = all_articles_df['company_in_title'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
all_articles_df['company_in_text'] = all_articles_df['company_in_text'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])


# Filter for Apple-related articles
title_enron = title_scandal_df[title_scandal_df['company_in_title'].apply(lambda x: 'Apple' in x)]
text_enron = all_articles_df[all_articles_df['company_in_text'].apply(lambda x: 'Apple' in x)]
all_enron = all_articles_df[all_articles_df['company_in_title'].apply(lambda x: 'Apple' in x)]

# Filter dates
start_date = pd.to_datetime('2014-08-01').date()
end_date = pd.to_datetime('2014-11-01').date()

title_enron['Date'] = title_enron['Date'].dt.date
text_enron['Date'] = text_enron['Date'].dt.date
all_enron['Date'] = all_enron['Date'].dt.date

title_enron = title_enron[(title_enron['Date'] >= start_date) & (title_enron['Date'] <= end_date)]
text_enron = text_enron[(text_enron['Date'] >= start_date) & (text_enron['Date'] <= end_date)]
all_enron = all_enron[(all_enron['Date'] >= start_date) & (all_enron['Date'] <= end_date)]

# Load stock data
stock_data = pd.read_excel('../Stock_Final.xlsx', sheet_name=5)
stock_data['Date'] = pd.to_datetime(stock_data['Date'], errors='coerce').dt.date

# Drop rows with invalid dates or missing stock prices
stock_data.dropna(subset=['Date', 'PX_VOLUME'], inplace=True)

# Filter the stock data for the desired date range
stock_data = stock_data[(stock_data['Date'] >= start_date) & (stock_data['Date'] <= end_date)]

# Count the number of articles per day for each dataset
articles_per_day_title = title_enron.groupby('Date').size().reset_index(name='Article_Count_Title')
articles_per_day_text = text_enron.groupby('Date').size().reset_index(name='Article_Count_Text')
articles_per_day_all = all_enron.groupby('Date').size().reset_index(name='Article_Count_All')

# Merge the trading volume data with the articles count data
merged_df = pd.merge(stock_data, articles_per_day_title, on='Date', how='left').fillna(0)
merged_df = pd.merge(merged_df, articles_per_day_text, on='Date', how='left').fillna(0)
merged_df = pd.merge(merged_df, articles_per_day_all, on='Date', how='left').fillna(0)

# Function to format y-axis in millions
def millions(x, pos):
    return '%1.0fM' % (x * 1e-6)

# Create a formatter for the y-axis
formatter = FuncFormatter(millions)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Bar chart for trading volume
ax1.bar(merged_df['Date'], merged_df['PX_VOLUME'], color='#a2cffe', alpha=0.6, label='Trading Volume')
ax1.yaxis.set_major_formatter(formatter)  # Apply the formatter to the y-axis

# Line chart for number of articles (title-based)
ax2 = ax1.twinx()
ax2.plot(merged_df['Date'], merged_df['Article_Count_Title'], color='#ffb347', alpha=0.8, label='Scandal Articles based on Title', linewidth=2)

# Line chart for number of articles (text-based)
ax2.plot(merged_df['Date'], merged_df['Article_Count_Text'], color='#ff6961', alpha=0.8, label='Scandal Articles based on Text', linewidth=2)

# Line chart for number of articles (all articles with Enron in title)
ax2.plot(merged_df['Date'], merged_df['Article_Count_All'], color='#c3a284', alpha=0.8, label='All Articles', linewidth=2)

# Add labels and title
ax1.set_xlabel('Date')
ax1.set_ylabel('Trading Volume (Millions)', color='#1f77b4')
ax2.set_ylabel('Number of Articles')
ax2.set_ylim(bottom=0)  # Ensure y-axis starts at 0
plt.title('Apple Trading Volume and Number of Articles Per Day')

# Legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Display plot
plt.show()
# Out:
# <ipython-input-51-8addb948062e>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   title_enron['Date'] = title_enron['Date'].dt.date
# <ipython-input-51-8addb948062e>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_enron['Date'] = text_enron['Date'].dt.date
# <ipython-input-51-8addb948062e>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_enron['Date'] = all_enron['Date'].dt.date

# %% [markdown]
# # Plot Descriptive Statistics

# %%
import pandas as pd
import numpy as np
import ast
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re

# Load the data from the provided CSV file to inspect the first few rows and the data structure
file_path = 'scandal_in_title.csv'
all_art = pd.read_csv(file_path)
all_art.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2670 entries, 0 to 2669
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2670 non-null   int64
#  1   GOID              2670 non-null   int64
#  2   Title             2670 non-null   object
#  3   Date              2670 non-null   object
#  4   words             2670 non-null   object
#  5   Titlebased        2670 non-null   float64
#  6   Textbased         2436 non-null   float64
#  7   company_in_title  2670 non-null   object
#  8   company_in_text   2629 non-null   object
#  9   scandal_in_title  2670 non-null   object
#  10  scandal_in_text   2444 non-null   object
#  11  GPT               5 non-null      object
#  12  scandals_manual   570 non-null    object
#  13  scandals_all      5 non-null      object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 292.2+ KB

# %%
# Function to transform list strings into comma-separated words
def transform_list_string(column):
    return column.apply(lambda x: ', '.join(ast.literal_eval(x)) if pd.notnull(x) else x)

# Identify columns to transform
columns_to_transform = ['words', 'company_in_title', 'company_in_text', 'scandal_in_title', 'scandal_in_text']

# Apply transformation
for col in columns_to_transform:
    if col in all_art.columns:
        all_art[col] = transform_list_string(all_art[col])

# %%
all_art['company_in_title'] = all_art['company_in_title'].apply(lambda x: x.split(', ') if isinstance(x, str) else [])
data_exploded = all_art.explode('company_in_title')

# Count the occurrences of each company
company_counts = data_exploded['company_in_title'].value_counts()

# Count the occurrences of each company
company_counts = data_exploded['company_in_title'].value_counts()

# Select the top 15 companies with the most occurrences
top_15_companies = company_counts.head(15)

# Define shades of blue (reversed to make the most cited one the darkest)
blue_shades = [
    '#004040',  # Deepest blue
    '#005560',  # Navyish blue
    '#006C80',  # Darker blue
    '#0083A0',  # Dark blue
    '#009AC0',  # Deep blue
    '#00B1FF',  # Strong blue
    '#1AB9FF',  # Cerulean blue
    '#33C0FF',  # Azure blue
    '#4CC8FF',  # Bright blue
    '#66CFFF',  # Medium light blue
    '#7FD7FF',  # Soft blue
    '#99DFFF',  # Sky blue
    '#B2E7FF',  # Light blue
    '#CCEFFF',  # Lighter blue
    '#E6F7FF'   # Very light blue
]

# Make sure we have enough colors for the top 15 companies
colors = blue_shades[:len(top_15_companies)]

# Create the pie chart
plt.figure(figsize=(10, 8))
plt.pie(top_15_companies, labels=top_15_companies.index, autopct='%1.1f%%', colors=colors, startangle=90)
plt.title('Top 15 Companies with Most NYT Articles Related to Scandals')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the pie chart
plt.show()

# %%
import pandas as pd
import numpy as np
import ast
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import matplotlib.pyplot as plt



# Load the data from the provided CSV file to inspect the first few rows and the data structure
file_path = 'scandal_in_title.csv'
all_art = pd.read_csv(file_path)
all_art.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2670 entries, 0 to 2669
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2670 non-null   int64
#  1   GOID              2670 non-null   int64
#  2   Title             2670 non-null   object
#  3   Date              2670 non-null   object
#  4   words             2670 non-null   object
#  5   Titlebased        2670 non-null   float64
#  6   Textbased         2436 non-null   float64
#  7   company_in_title  2670 non-null   object
#  8   company_in_text   2629 non-null   object
#  9   scandal_in_title  2670 non-null   object
#  10  scandal_in_text   2444 non-null   object
#  11  GPT               5 non-null      object
#  12  scandals_manual   570 non-null    object
#  13  scandals_all      5 non-null      object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 292.2+ KB

# %%
# Extracting years
all_art['Year'] = pd.to_datetime(all_art['Date']).dt.year

# Create an empty dictionary to store the number of mentions for each company each year
yearly_company_counts = {}

# Iterate through each row of data
for index, row in all_art.iterrows():
    year = row['Year']  # Get the year
    companies_str = row['company_in_title']  # Get the company list string

    # Ensure companies_str is a string
    if not isinstance(companies_str, str):
        continue

    # Use regular expressions to extract company names, i.e., those contained within single quotes and square brackets
    companies_list = re.findall(r"'([^']*)'", companies_str)
    
    # Iterate through each extracted company name
    for company in companies_list:
        # Remove leading and trailing spaces, and convert to uppercase
        cleaned_company = company.strip().upper()
        # Check if the company is in yearly_company_counts
        if cleaned_company in yearly_company_counts:
            # Check if the year already exists in the count for that company
            if year in yearly_company_counts[cleaned_company]:
                yearly_company_counts[cleaned_company][year] += 1
            else:
                yearly_company_counts[cleaned_company][year] = 1
        else:
            yearly_company_counts[cleaned_company] = {year: 1}

# Map for displaying proper capitalization in the legend
company_display_names = {
    'MICROSOFT': 'Microsoft',
    'GOOGLE': 'Google',
    'ENRON': 'Enron',
    'INTEL': 'Intel',
    'FACEBOOK': 'Facebook',
    'APPLE': 'Apple',
    'CITI': 'Citi',
    'BOFA': 'Bank of America',
    'AMAZON': 'Amazon',
    'BOEING': 'Boeing',
    'HEALTHSOUTH': 'HealthSouth'
}

# Select the specific companies of interest
selected_companies = ['MICROSOFT', 'GOOGLE', 'ENRON', 'INTEL', 'FACEBOOK', 'APPLE', 'CITI', 'BOFA', 'AMAZON', 'BOEING', 'HEALTHSOUTH']

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(yearly_company_counts, orient='index').fillna(0)

# Reorder columns in the desired order of company names
df = df.transpose()
sorted_df = df.sort_index(axis=0)

# Create an empty DataFrame to store the selected columns
selected_df = pd.DataFrame()

# Iterate through the selected companies list
for company in selected_companies:
    # Check if the company name column exists in the DataFrame
    if company in sorted_df.columns:
        # If it exists, add the column to the selected DataFrame
        selected_df[company_display_names[company]] = sorted_df[company]

# Normalize the data by dividing each company's count by the total count for that year
normalized_df = selected_df.div(selected_df.sum(axis=1), axis=0)

# Generate a gradient of shades from the base color
base_color = '#1f77b4'
num_shades = len(selected_companies)
colors = [mcolors.to_hex(plt.cm.Blues(i / (num_shades - 1))) for i in range(num_shades)]
colors.reverse()  # Reverse the order to have the darkest color at the bottom

# Plot the stacked bar chart with normalized data and gradient of shades
ax = selected_df.plot(kind='bar', stacked=True, figsize=(12, 7), color=colors)
ax.set_ylabel('Number of Mentions')
ax.set_xlabel('Year')
ax.set_title('Annual Count of NYT Articles on Companies with the Most Scandals')
plt.legend(title='Companies', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('selected_scandalous_companies_distribution.png')
plt.show()

# %%
# Extracting years
all_art['Year'] = pd.to_datetime(all_art['Date']).dt.year

# Create an empty dictionary to store the number of mentions for each company each year
yearly_company_counts = {}

# Iterate through each row of data
for index, row in all_art.iterrows():
    year = row['Year']  # Get the year
    companies_str = row['company_in_title']  # Get the company list string

    # Ensure companies_str is a string
    if not isinstance(companies_str, str):
        continue

    # Use regular expressions to extract company names, i.e., those contained within single quotes and square brackets
    companies_list = re.findall(r"'([^']*)'", companies_str)
    
    # Iterate through each extracted company name
    for company in companies_list:
        # Remove leading and trailing spaces, and convert to uppercase
        cleaned_company = company.strip().upper()
        # Check if the company is in yearly_company_counts
        if cleaned_company in yearly_company_counts:
            # Check if the year already exists in the count for that company
            if year in yearly_company_counts[cleaned_company]:
                yearly_company_counts[cleaned_company][year] += 1
            else:
                yearly_company_counts[cleaned_company][year] = 1
        else:
            yearly_company_counts[cleaned_company] = {year: 1}

# Map for displaying proper capitalization in the legend
company_display_names = {
    'MICROSOFT': 'Microsoft',
    'GOOGLE': 'Google',
    'ENRON': 'Enron',
    'INTEL': 'Intel',
    'FACEBOOK': 'Facebook',
    'APPLE': 'Apple',
    'CITI': 'Citi',
    'BOFA': 'Bank of America',
    'AMAZON': 'Amazon',
    'BOEING': 'Boeing',
    'HEALTHSOUTH': 'HealthSouth'
}

# Select the specific companies of interest
selected_companies = ['MICROSOFT', 'GOOGLE', 'ENRON', 'INTEL', 'FACEBOOK', 'APPLE', 'CITI', 'BOFA', 'AMAZON', 'BOEING', 'HEALTHSOUTH']

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(yearly_company_counts, orient='index').fillna(0)

# Reorder columns in the desired order of company names
df = df.transpose()
sorted_df = df.sort_index(axis=0)

# Create an empty DataFrame to store the selected columns
selected_df = pd.DataFrame()

# Iterate through the selected companies list
for company in selected_companies:
    # Check if the company name column exists in the DataFrame
    if company in sorted_df.columns:
        # If it exists, add the column to the selected DataFrame
        selected_df[company_display_names[company]] = sorted_df[company]

# Normalize the data by dividing each company's count by the total count for the selected companies that year
normalized_df = selected_df.div(selected_df.sum(axis=1), axis=0)

# Generate a gradient of shades from the base color
base_color = '#1f77b4'
num_shades = len(selected_companies)
colors = [mcolors.to_hex(plt.cm.Blues(i / (num_shades - 1))) for i in range(num_shades)]
colors.reverse()  # Reverse the order to have the darkest color at the bottom

# Plot the stacked bar chart with normalized data and gradient of shades
ax = normalized_df.plot(kind='bar', stacked=True, figsize=(12, 7), color=colors)
ax.set_ylabel('Percentage of Mentions')
ax.set_xlabel('Year')
ax.set_title('Annual Distribution of WSJ Articles on Companies with the Most Scandals in Percentage')
plt.legend(title='Companies', bbox_to_anchor=(1.05, 1), loc='upper left')

# Set the y-axis labels to be percentages
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x * 100)}%'))

plt.tight_layout()
plt.savefig('selected_scandalous_companies_distribution_percentage.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# Load your dataset (assuming the DataFrame is already loaded as 'all_art')
# Make sure the 'Date' and 'company_in_title' columns exist in the DataFrame
if 'Date' not in all_art.columns or 'company_in_title' not in all_art.columns:
    raise ValueError("The DataFrame must contain 'Date' and 'company_in_title' columns")

# Extracting years
all_art['Year'] = pd.to_datetime(all_art['Date']).dt.year

# Create an empty dictionary to store the number of articles each year
yearly_article_counts = {}

# Iterate through each row of data
for index, row in all_art.iterrows():
    year = row['Year']  # Get the year
    if year in yearly_article_counts:
        yearly_article_counts[year] += 1
    else:
        yearly_article_counts[year] = 1

# Convert the dictionary to a DataFrame
yearly_article_counts_df = pd.DataFrame(list(yearly_article_counts.items()), columns=['Year', 'Total Articles'])

# Sort the DataFrame by year
yearly_article_counts_df = yearly_article_counts_df.sort_values(by='Year')

# Plot the bar chart
plt.figure(figsize=(14, 8))
plt.bar(yearly_article_counts_df['Year'], yearly_article_counts_df['Total Articles'], color='#1f77b4')
plt.xlabel('Year')
plt.ylabel('Total Number of Articles')
plt.title('Total Number of WSJ Scandal Articles about Companies Published Per Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('total_scandal_articles_per_year.png')
plt.show()

# %% [markdown]
# ## Distribution of top scandal terms

# %%
import pandas as pd
import numpy as np
import ast
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re


data = pd.read_csv("scandal_in_title.csv")
data
# Out:
#       Unnamed: 0        GOID  \
# 0            103  1031258266
# 1            145  1001889515
# 2            255  1139457592
# 3            306  1352262368
# 4            476  1026851789
# ...          ...         ...
# 2665       95651   926639928
# 2666       95681   927545526
# 2667       95686   963817467
# 2668       95846   929469066
# 2669       95915   929078101
#
#                                                   Title        Date  \
# 0     Corporate News: AMR Faces $162 Million in Pena...  2012-08-07
# 1                        Samsung, Apple Seek Settlement  2012-04-18
# 2      Global Finance: J.P. Morgan Nears SEC Settlement  2012-11-07
# 3          Inventive Google Arrests Apple's Development  2013-05-17
# 4                     BofA Hit by Ghost of Housing Past  2012-07-19
# ...                                                 ...         ...
# 2665  U.S. Warns Apple, Publishers --- Justice Depar...  2012-03-08
# 2666  Examiner Rips Dynegy Move --- Asset Transfer B...  2012-03-10
# 2667  Global Finance: Fed Seeks Dismissal of Greenbe...  2012-04-04
# 2668  Corporate News: Brazil Charges Chevron --- Oil...  2012-03-22
# 2669  Chevron Hits Troubled Waters --- Brazil Plans ...  2012-03-20
#
#                                                   words  Titlebased  \
# 0     ["Federal Aviation Administration seeking reco...         1.0
# 1     ['Apple Inc. Samsung Electronics Co. agreed en...         1.0
# 2     ["J.P. Morgan Chase & Co. close settlement Sec...         1.0
# 3     ["[Financial Analysis Commentary] Tech investo...         1.0
# 4     ['falling improved net profit. ready Olympics....         1.0
# ...                                                 ...         ...
# 2665  ['Justice Department warned Apple Inc. five bi...         1.0
# 2666  ["bankruptcy-court examiner said Dynegy Inc.'s...         1.0
# 2667  ['Federal Reserve Bank New York asked Manhatta...         1.0
# 2668  ['SAO PAULO -- Brazilian prosecutor filed crim...         1.0
# 2669  ["Brazilian prosecutors' planned criminal char...         1.0
#
#       Textbased     company_in_title  \
# 0           1.0              ['AMR']
# 1           1.0            ['Apple']
# 2           1.0      ['J.P. Morgan']
# 3           NaN  ['Apple', 'Google']
# 4           1.0             ['BofA']
# ...         ...                  ...
# 2665        1.0            ['Apple']
# 2666        1.0           ['Dynegy']
# 2667        1.0              ['AIG']
# 2668        1.0          ['Chevron']
# 2669        1.0          ['Chevron']
#
#                                         company_in_text scandal_in_title  \
# 0                                     ['Boeing', 'AMR']     ['penalt__']
# 1                                             ['Apple']   ['settlement']
# 2     ['Chase', 'Fannie Mae', 'Freddie Mac', 'Wells ...   ['settlement']
# 3     ['Facebook', 'Microsoft', 'Apple', 'Amazon.com...     ['arrest__']
# 4     ['Chase', 'Countrywide Financial', 'Wells Farg...      ['ghost__']
# ...                                                 ...              ...
# 2665  ['Barnes & Noble', 'Apple', 'CBS', 'Amazon', '...     ['collus__']
# 2666                              ['Dynegy', 'Tribune']   ['fraudulent']
# 2667                                     ['AIG', 'AIG']      ['lawsuit']
# 2668                                        ['Chevron']       ['leak__']
# 2669     ['Anadarko Petroleum', 'Chevron', 'Jefferies']       ['leak__']
#
#                          scandal_in_text  GPT scandals_manual scandals_all
# 0                           ['penalt__']  NaN             NaN          NaN
# 1                         ['settlement']  NaN             NaN          NaN
# 2     ['lawsuit', 'settlement', 'fraud']  NaN               Y          NaN
# 3                                    NaN  NaN             NaN          NaN
# 4                           ['breach__']  NaN             NaN          NaN
# ...                                  ...  ...             ...          ...
# 2665          ['violat__', 'settlement']  NaN               Y          NaN
# 2666                        ['breach__']  NaN             NaN          NaN
# 2667           ['lawsuit', 'improper__']  NaN             NaN          NaN
# 2668                          ['leak__']  NaN               Y          NaN
# 2669                          ['leak__']  NaN             NaN          NaN
#
# [2670 rows x 14 columns]

# %%
# Function to transform list strings into comma-separated words - easier to handle
def transform_list_string(column):
    return column.apply(lambda x: ', '.join(ast.literal_eval(x)) if pd.notnull(x) else x)

# Identify columns to transform
columns_to_transform = ['words', 'company_in_title', 'company_in_text', 'scandal_in_title', 'scandal_in_text']

# Apply transformation
for col in columns_to_transform:
    if col in data.columns:
        data[col] = transform_list_string(data[col])

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/giuseppebaccaro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Convert 'Date' to datetime format and extract the year
data['Year'] = pd.to_datetime(data['Date']).dt.year

# Handle missing values in 'scandal_in_title' column
data['scandal_in_title'] = data['scandal_in_title'].fillna('')

# Create a list of scandal words from 'scandal_in_title' column
data['scandal_in_title'] = data['scandal_in_title'].apply(lambda x: x.split('__') if x != '' else [])

# Explode the dataframe so each scandal term has its own row
expanded_data = data.explode('scandal_in_title')

# Count the occurrences of each scandal term per year
count_per_year = expanded_data.groupby(['Year', 'scandal_in_title']).size().unstack(fill_value=0)

# Identify the top 10 scandal words by their total frequency over all years
top_scandals = count_per_year.sum(axis=0).nlargest(10).index

# Sort the scandal terms by total frequency from highest to lowest
sorted_scandals = count_per_year[top_scandals].sum().sort_values(ascending=False).index

# Define a base color
base_color = '#1f77b4'

# Plotting
plt.figure(figsize=(20, 8))
bar_width = 0.8
years = count_per_year.index
num_scandals = len(sorted_scandals)

# Initialize a base for the bar stacking
base = np.zeros(len(years))

# Loop to plot each scandal term, starting with the most frequent at the bottom
for i, scandal in enumerate(sorted_scandals):
    # Calculate the color intensity based on position, darker for higher frequency
    color_intensity = 1 - (i / num_scandals)  # Invert to have darker colors for more frequent terms
    color = plt.cm.Blues(color_intensity)  # Get color from the 'Blues' colormap

    # Plot the bar
    plt.bar(years, count_per_year[scandal], width=bar_width, label=scandal, color=color, bottom=base)

    # Update the base for the next bar
    base += count_per_year[scandal]

plt.title('Distribution of Top 10 Scandal Terms Over Time')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.legend(title='Scandal Terms', loc='upper left', bbox_to_anchor=(1.05, 1))
plt.grid(True, axis='y')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Plot the Frequency Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
from collections import Counter

# Take our dictionary
keywords = [
    "corrupt.*", "deceit.*", "decept.*", "deceiv.*", "betray.*", "shame.*", 
    "scandal.*", "dishonest.*", "misconduct.*", "fraud", "illegal.*", 
    "unethic.*", "violat.*", "falsify.*", "breach.*", "leak.*", "pollut.*", 
    "insecur.*", "irregular.*", "mismanag.*", "inappropriat.*", "unlaw.*", 
    "transgress.*", "noncomplian.*", "non-complian.*", "ghost.*", "malfeas.*", 
    "exploitat.*", "discriminat.*", "harass.*", "misrepresent.*", "embezzle.*", 
    "improper.*", "espion.*", "collus.*", "misus.*", "rigg.*", "kickback.*", 
    "retaliat.*", "moral lapse", "insider trading", "insider dealing", 
    "ponzi scheme", "arrest.*", "product recall", "privacy breach", 
    "privacy violation.*", "data leak", "intellectual property dispute", 
    "malpracti.*", "destruct.*", "unsustain.*", "ESG scandal", "fraudulent", 
    "deceptiv.*", "scamm.*", "briber.*", "bribe.*", "extort.*", 
    "misappropriat.*", "sabotag.*", "deforest.*", "habitat destruct.*", 
    "climate change deni.*", "tax evasion", "money launder.*", 
    "accounting scandal", "whistleblow.*", "sexual harass.*", 
    "workplace harass.*", "toxic culture", "data breach", "ransomware", 
    "drug recall", "clinical trial fraud", "off-label marketing", "antitrust", 
    "cartel", "monopoly", "litigat.*", "regulatory breach", "cover-up", 
    "settlement", "lawsuit", "penalt.*"
]

# Compile the regular expressions for efficiency
keyword_patterns = [re.compile(keyword, re.IGNORECASE) for keyword in keywords]

# Initialize a counter for the keywords
keyword_counter = Counter()

# Iterate through the titles and count keyword matches
for title in data['Title']:
    for pattern in keyword_patterns:
        if pattern.search(title):
            keyword_counter[pattern.pattern] += 1

# Convert the counter to a DataFrame for plotting
scandal_df = pd.DataFrame.from_dict(keyword_counter, orient='index', columns=['Count']).reset_index()
scandal_df.rename(columns={'index': 'Scandal'}, inplace=True)
scandal_df = scandal_df.sort_values(by='Count', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(20, 10))  # Increased figure size for better readability
plt.bar(scandal_df['Scandal'], scandal_df['Count'], color='#a2cffe', alpha=0.8)
plt.xlabel('Scandal Words', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.title('Most Used Scandal Words in Titles', fontsize=16)
plt.xticks(rotation=90, ha='center', fontsize=12)  # Changed rotation and increased font size
plt.tight_layout()

# Display plot
plt.show()

# %% [markdown]
# ## Plot the Occurence Plot

# %%
import pandas as pd
import numpy as np
import ast
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import seaborn as sns
from collections import defaultdict, Counter
from sklearn.feature_extraction.text import CountVectorizer



data = pd.read_csv("scandal_in_title.csv")
data
# Out:
#       Unnamed: 0        GOID  \
# 0            103  1031258266
# 1            145  1001889515
# 2            255  1139457592
# 3            306  1352262368
# 4            476  1026851789
# ...          ...         ...
# 2665       95651   926639928
# 2666       95681   927545526
# 2667       95686   963817467
# 2668       95846   929469066
# 2669       95915   929078101
#
#                                                   Title        Date  \
# 0     Corporate News: AMR Faces $162 Million in Pena...  2012-08-07
# 1                        Samsung, Apple Seek Settlement  2012-04-18
# 2      Global Finance: J.P. Morgan Nears SEC Settlement  2012-11-07
# 3          Inventive Google Arrests Apple's Development  2013-05-17
# 4                     BofA Hit by Ghost of Housing Past  2012-07-19
# ...                                                 ...         ...
# 2665  U.S. Warns Apple, Publishers --- Justice Depar...  2012-03-08
# 2666  Examiner Rips Dynegy Move --- Asset Transfer B...  2012-03-10
# 2667  Global Finance: Fed Seeks Dismissal of Greenbe...  2012-04-04
# 2668  Corporate News: Brazil Charges Chevron --- Oil...  2012-03-22
# 2669  Chevron Hits Troubled Waters --- Brazil Plans ...  2012-03-20
#
#                                                   words  Titlebased  \
# 0     ["Federal Aviation Administration seeking reco...         1.0
# 1     ['Apple Inc. Samsung Electronics Co. agreed en...         1.0
# 2     ["J.P. Morgan Chase & Co. close settlement Sec...         1.0
# 3     ["[Financial Analysis Commentary] Tech investo...         1.0
# 4     ['falling improved net profit. ready Olympics....         1.0
# ...                                                 ...         ...
# 2665  ['Justice Department warned Apple Inc. five bi...         1.0
# 2666  ["bankruptcy-court examiner said Dynegy Inc.'s...         1.0
# 2667  ['Federal Reserve Bank New York asked Manhatta...         1.0
# 2668  ['SAO PAULO -- Brazilian prosecutor filed crim...         1.0
# 2669  ["Brazilian prosecutors' planned criminal char...         1.0
#
#       Textbased     company_in_title  \
# 0           1.0              ['AMR']
# 1           1.0            ['Apple']
# 2           1.0      ['J.P. Morgan']
# 3           NaN  ['Apple', 'Google']
# 4           1.0             ['BofA']
# ...         ...                  ...
# 2665        1.0            ['Apple']
# 2666        1.0           ['Dynegy']
# 2667        1.0              ['AIG']
# 2668        1.0          ['Chevron']
# 2669        1.0          ['Chevron']
#
#                                         company_in_text scandal_in_title  \
# 0                                     ['Boeing', 'AMR']     ['penalt__']
# 1                                             ['Apple']   ['settlement']
# 2     ['Chase', 'Fannie Mae', 'Freddie Mac', 'Wells ...   ['settlement']
# 3     ['Facebook', 'Microsoft', 'Apple', 'Amazon.com...     ['arrest__']
# 4     ['Chase', 'Countrywide Financial', 'Wells Farg...      ['ghost__']
# ...                                                 ...              ...
# 2665  ['Barnes & Noble', 'Apple', 'CBS', 'Amazon', '...     ['collus__']
# 2666                              ['Dynegy', 'Tribune']   ['fraudulent']
# 2667                                     ['AIG', 'AIG']      ['lawsuit']
# 2668                                        ['Chevron']       ['leak__']
# 2669     ['Anadarko Petroleum', 'Chevron', 'Jefferies']       ['leak__']
#
#                          scandal_in_text  GPT scandals_manual scandals_all
# 0                           ['penalt__']  NaN             NaN          NaN
# 1                         ['settlement']  NaN             NaN          NaN
# 2     ['lawsuit', 'settlement', 'fraud']  NaN               Y          NaN
# 3                                    NaN  NaN             NaN          NaN
# 4                           ['breach__']  NaN             NaN          NaN
# ...                                  ...  ...             ...          ...
# 2665          ['violat__', 'settlement']  NaN               Y          NaN
# 2666                        ['breach__']  NaN             NaN          NaN
# 2667           ['lawsuit', 'improper__']  NaN             NaN          NaN
# 2668                          ['leak__']  NaN               Y          NaN
# 2669                          ['leak__']  NaN             NaN          NaN
#
# [2670 rows x 14 columns]

# %%
# Function to transform list strings into comma-separated words - easier to handle
def transform_list_string(column):
    return column.apply(lambda x: ', '.join(ast.literal_eval(x)) if pd.notnull(x) else x)


columns_to_transform = ['words', 'company_in_title', 'company_in_text', 'scandal_in_title', 'scandal_in_text']


for col in columns_to_transform:
    if col in data.columns:
        data[col] = transform_list_string(data[col])

# %%
titles = data[['Title', 'company_in_title', 'scandal_in_title']]
scandal_titles = titles[titles['scandal_in_title'].notna()]

# Parse and tokenize the scandal-related words
def tokenize_scandal_words(scandal_str):
    return scandal_str.replace('__', ' ').replace(',', ' ').split()

scandal_titles['scandal_in_title'] = scandal_titles['scandal_in_title'].apply(lambda x: tokenize_scandal_words(x) if isinstance(x, str) else [])

all_scandals = [scandal for sublist in scandal_titles['scandal_in_title'] for scandal in sublist]
unique_scandals = list(set(all_scandals))

vectorizer = CountVectorizer(vocabulary=unique_scandals, lowercase=True, binary=True)
X = vectorizer.fit_transform(scandal_titles['Title'])


company_words = defaultdict(Counter)

for index, row in scandal_titles.iterrows():
    companies = row['company_in_title'].split(', ')
    title_vector = X[index].toarray()[0]
    for company in companies:
        company_words[company].update(dict(zip(unique_scandals, title_vector)))


company_counts = Counter()
for companies in scandal_titles['company_in_title']:
    for company in companies.split(', '):
        company_counts[company] += 1

top_companies = [company for company, count in company_counts.most_common(11)]


plot_data = []
for company in top_companies:
    top_words = company_words[company].most_common(11)  # Get top 10 scandal words for each company
    for word, freq in top_words:
        plot_data.append([company, word, freq])

df_plot = pd.DataFrame(plot_data, columns=['Company', 'Word', 'Frequency'])


df_plot['Frequency'] = df_plot['Frequency'] / df_plot.groupby('Company')['Frequency'].transform('sum')

plt.figure(figsize=(14, 10))
bubble_plot = sns.scatterplot(data=df_plot, x='Company', y='Word', size='Frequency', hue='Company', legend=False, sizes=(20, 2000), alpha=0.6)

plt.title('Top 10 Scandal Words in Titles Associated with Top 10 Companies')
plt.xlabel('Company')
plt.ylabel('Word')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
scandals = pd.read_csv("Scandal_in_title.csv", index_col=0)
scandals
# Out:
#              GOID                                              Title  \
# 103    1031258266  Corporate News: AMR Faces $162 Million in Pena...
# 145    1001889515                     Samsung, Apple Seek Settlement
# 255    1139457592   Global Finance: J.P. Morgan Nears SEC Settlement
# 306    1352262368       Inventive Google Arrests Apple's Development
# 476    1026851789                  BofA Hit by Ghost of Housing Past
# ...           ...                                                ...
# 95651   926639928  U.S. Warns Apple, Publishers --- Justice Depar...
# 95681   927545526  Examiner Rips Dynegy Move --- Asset Transfer B...
# 95686   963817467  Global Finance: Fed Seeks Dismissal of Greenbe...
# 95846   929469066  Corporate News: Brazil Charges Chevron --- Oil...
# 95915   929078101  Chevron Hits Troubled Waters --- Brazil Plans ...
#
#              Date                                              words  \
# 103    2012-08-07  ["Federal Aviation Administration seeking reco...
# 145    2012-04-18  ['Apple Inc. Samsung Electronics Co. agreed en...
# 255    2012-11-07  ["J.P. Morgan Chase & Co. close settlement Sec...
# 306    2013-05-17  ["[Financial Analysis Commentary] Tech investo...
# 476    2012-07-19  ['falling improved net profit. ready Olympics....
# ...           ...                                                ...
# 95651  2012-03-08  ['Justice Department warned Apple Inc. five bi...
# 95681  2012-03-10  ["bankruptcy-court examiner said Dynegy Inc.'s...
# 95686  2012-04-04  ['Federal Reserve Bank New York asked Manhatta...
# 95846  2012-03-22  ['SAO PAULO -- Brazilian prosecutor filed crim...
# 95915  2012-03-20  ["Brazilian prosecutors' planned criminal char...
#
#        Titlebased  Textbased     company_in_title  \
# 103           1.0        1.0              ['AMR']
# 145           1.0        1.0            ['Apple']
# 255           1.0        1.0      ['J.P. Morgan']
# 306           1.0        NaN  ['Apple', 'Google']
# 476           1.0        1.0             ['BofA']
# ...           ...        ...                  ...
# 95651         1.0        1.0            ['Apple']
# 95681         1.0        1.0           ['Dynegy']
# 95686         1.0        1.0              ['AIG']
# 95846         1.0        1.0          ['Chevron']
# 95915         1.0        1.0          ['Chevron']
#
#                                          company_in_text scandal_in_title  \
# 103                                    ['Boeing', 'AMR']     ['penalt__']
# 145                                            ['Apple']   ['settlement']
# 255    ['Chase', 'Fannie Mae', 'Freddie Mac', 'Wells ...   ['settlement']
# 306    ['Facebook', 'Microsoft', 'Apple', 'Amazon.com...     ['arrest__']
# 476    ['Chase', 'Countrywide Financial', 'Wells Farg...      ['ghost__']
# ...                                                  ...              ...
# 95651  ['Barnes & Noble', 'Apple', 'CBS', 'Amazon', '...     ['collus__']
# 95681                              ['Dynegy', 'Tribune']   ['fraudulent']
# 95686                                     ['AIG', 'AIG']      ['lawsuit']
# 95846                                        ['Chevron']       ['leak__']
# 95915     ['Anadarko Petroleum', 'Chevron', 'Jefferies']       ['leak__']
#
#                           scandal_in_text  GPT scandals_manual scandals_all
# 103                          ['penalt__']  NaN             NaN          NaN
# 145                        ['settlement']  NaN             NaN          NaN
# 255    ['lawsuit', 'settlement', 'fraud']  NaN               Y          NaN
# 306                                   NaN  NaN             NaN          NaN
# 476                          ['breach__']  NaN             NaN          NaN
# ...                                   ...  ...             ...          ...
# 95651          ['violat__', 'settlement']  NaN               Y          NaN
# 95681                        ['breach__']  NaN             NaN          NaN
# 95686           ['lawsuit', 'improper__']  NaN             NaN          NaN
# 95846                          ['leak__']  NaN               Y          NaN
# 95915                          ['leak__']  NaN             NaN          NaN
#
# [2670 rows x 13 columns]

# %%
annoted = pd.read_csv("ScandalsRevised.csv", index_col=0)
annoted
# Out:
#                                                      text  Unnamed: 2  \
# id
# 533312  Google Argues Case Against $9 Billion In Antit...      307078
# 533313  British Ex-Bankers Sentenced For Their Roles i...      699620
# 533314  Procter &amp; Gamble Co.: Gillette and Schick-...      718378
# 533315  Merck &amp; Co.: Vioxx Lawsuit Is Dropped By W...      810805
# 533316              Intel to Pay Intergraph in Settlement      602242
# ...                                                   ...         ...
# 533907  The Mossberg Solution: Music That You Don't Ha...      550214
# 533908  Google Dodges Antitrust Hit --- FTC Extracts L...        7485
# 533909  WorldCom-Sprint Merger Faces Setback --- Justi...      454117
# 533910  Advanced Micro Devices Inc.: Antitrust Case Ag...      764312
# 533911  Business News: U.K. Agency Fines Pfizer $107 M...      180167
#
#              Date label  Comments
# id
# 533312  2020/2/13     Y       NaN
# 533313  2008/2/25     Y       NaN
# 533314  2006/2/17     Y       NaN
# 533315  2007/1/23     Y       NaN
# 533316  2004/3/31     Y       NaN
# ...           ...   ...       ...
# 533907  2003/4/30   NaN       NaN
# 533908   2013/1/4     Y       NaN
# 533909  2000/5/18     Y       NaN
# 533910  2006/9/28     Y       NaN
# 533911  2016/12/8     Y       NaN
#
# [600 rows x 5 columns]

# %%
merged_df = pd.merge(scandals, annoted, left_on='Title', right_on='text', how='inner')
merged_df
# Out:
#            GOID                                              Title  \
# 0    1139457592   Global Finance: J.P. Morgan Nears SEC Settlement
# 1    1266467867   Corporate News: Behind Google's Antitrust Escape
# 2    1266705087  Google Dodges Antitrust Hit --- FTC Extracts L...
# 3    1081119360  BofA Takes New Crisis-Era Hit --- Shareholder ...
# 4    1018854278  Oil Giants Launch Bribe Probes --- Eni, Chevro...
# ..          ...                                                ...
# 595   900761500     Judge to Citi and SEC: Explain Your Settlement
# 596   919647912    Woman Charged With Extorting Yankees GM Cashman
# 597   912251643                 Oracle's Ghost of Christmas Future
# 598   926639928  U.S. Warns Apple, Publishers --- Justice Depar...
# 599   929469066  Corporate News: Brazil Charges Chevron --- Oil...
#
#          Date_x                                              words  \
# 0    2012-11-07  ["J.P. Morgan Chase & Co. close settlement Sec...
# 1    2013-01-05  ['early hopes sweeping antitrust case Google I...
# 2    2013-01-04  ["U.S. antitrust regulators spent nearly two y...
# 3    2012-09-29  ['Bank America Corp. agreed pay $2.43 billion ...
# 4    2012-06-07  ["Kazakhstan's Aksai City, dusty outpost acros...
# ..          ...                                                ...
# 595  2011-10-28  ["used resolve securities-enforcement cases, q...
# 596  2012-02-03                                                 []
# 597  2011-12-22  ["[Financial Analysis Commentary] Oracle share...
# 598  2012-03-08  ['Justice Department warned Apple Inc. five bi...
# 599  2012-03-22  ['SAO PAULO -- Brazilian prosecutor filed crim...
#
#      Titlebased  Textbased    company_in_title  \
# 0           1.0        1.0     ['J.P. Morgan']
# 1           1.0        1.0          ['Google']
# 2           1.0        1.0          ['Google']
# 3           1.0        1.0            ['BofA']
# 4           1.0        1.0         ['Chevron']
# ..          ...        ...                 ...
# 595         1.0        1.0            ['Citi']
# 596         1.0        NaN  ['General Motors']
# 597         1.0        NaN          ['Oracle']
# 598         1.0        1.0           ['Apple']
# 599         1.0        1.0         ['Chevron']
#
#                                        company_in_text scandal_in_title  \
# 0    ['Chase', 'Fannie Mae', 'Freddie Mac', 'Wells ...   ['settlement']
# 1                              ['Google', 'Microsoft']    ['antitrust']
# 2    ['Microsoft', 'Apple', 'Goldman', 'Expedia', '...    ['antitrust']
# 3    ['Merrill Lynch', 'BofA', 'Countrywide Financi...      ['lawsuit']
# 4                                          ['Chevron']      ['bribe__']
# ..                                                 ...              ...
# 595  ['Goldman', 'Citi', 'Merrill Lynch', 'Goldman'...   ['settlement']
# 596                                                NaN     ['extort__']
# 597        ['Oracle', 'Microsoft', 'Sun Microsystems']      ['ghost__']
# 598  ['Barnes & Noble', 'Apple', 'CBS', 'Amazon', '...     ['collus__']
# 599                                        ['Chevron']       ['leak__']
#
#                             scandal_in_text  GPT scandals_manual scandals_all  \
# 0        ['lawsuit', 'settlement', 'fraud']  NaN               Y          NaN
# 1      ['lawsuit', 'antitrust', 'violat__']  NaN               Y          NaN
# 2    ['misus__', 'antitrust', 'settlement']  NaN               Y          NaN
# 3               ['settlement', 'litigat__']  NaN               Y          NaN
# 4                              ['briber__']  NaN               Y          NaN
# ..                                      ...  ...             ...          ...
# 595     ['penalt__', 'settlement', 'fraud']  NaN               Y          NaN
# 596                                     NaN  NaN               Y          NaN
# 597                                     NaN  NaN               Y          NaN
# 598              ['violat__', 'settlement']  NaN               Y          NaN
# 599                              ['leak__']  NaN               Y          NaN
#
#                                                   text  Unnamed: 2  \
# 0     Global Finance: J.P. Morgan Nears SEC Settlement        3753
# 1     Corporate News: Behind Google's Antitrust Escape        7242
# 2    Google Dodges Antitrust Hit --- FTC Extracts L...        7485
# 3    BofA Takes New Crisis-Era Hit --- Shareholder ...       11831
# 4    Oil Giants Launch Bribe Probes --- Eni, Chevro...       14185
# ..                                                 ...         ...
# 595     Judge to Citi and SEC: Explain Your Settlement      917288
# 596    Woman Charged With Extorting Yankees GM Cashman      917999
# 597                 Oracle's Ghost of Christmas Future      920891
# 598  U.S. Warns Apple, Publishers --- Justice Depar...      921746
# 599  Corporate News: Brazil Charges Chevron --- Oil...      924862
#
#          Date_y label  Comments
# 0     2012/11/7     Y       NaN
# 1      2013/1/5     Y       NaN
# 2      2013/1/4     Y       NaN
# 3     2012/9/29     Y       NaN
# 4      2012/6/7     Y       NaN
# ..          ...   ...       ...
# 595  2011/10/28     Y       NaN
# 596    2012/2/3     Y       NaN
# 597  2011/12/22     Y       NaN
# 598    2012/3/8     Y       NaN
# 599   2012/3/22     Y       NaN
#
# [600 rows x 18 columns]

# %%
merged_df = merged_df.drop(columns=['Unnamed: 2','Date_y','Comments'])

# %%
merged_df
# Out:
#            GOID                                              Title  \
# 0    1139457592   Global Finance: J.P. Morgan Nears SEC Settlement
# 1    1266467867   Corporate News: Behind Google's Antitrust Escape
# 2    1266705087  Google Dodges Antitrust Hit --- FTC Extracts L...
# 3    1081119360  BofA Takes New Crisis-Era Hit --- Shareholder ...
# 4    1018854278  Oil Giants Launch Bribe Probes --- Eni, Chevro...
# ..          ...                                                ...
# 595   900761500     Judge to Citi and SEC: Explain Your Settlement
# 596   919647912    Woman Charged With Extorting Yankees GM Cashman
# 597   912251643                 Oracle's Ghost of Christmas Future
# 598   926639928  U.S. Warns Apple, Publishers --- Justice Depar...
# 599   929469066  Corporate News: Brazil Charges Chevron --- Oil...
#
#          Date_x                                              words  \
# 0    2012-11-07  ["J.P. Morgan Chase & Co. close settlement Sec...
# 1    2013-01-05  ['early hopes sweeping antitrust case Google I...
# 2    2013-01-04  ["U.S. antitrust regulators spent nearly two y...
# 3    2012-09-29  ['Bank America Corp. agreed pay $2.43 billion ...
# 4    2012-06-07  ["Kazakhstan's Aksai City, dusty outpost acros...
# ..          ...                                                ...
# 595  2011-10-28  ["used resolve securities-enforcement cases, q...
# 596  2012-02-03                                                 []
# 597  2011-12-22  ["[Financial Analysis Commentary] Oracle share...
# 598  2012-03-08  ['Justice Department warned Apple Inc. five bi...
# 599  2012-03-22  ['SAO PAULO -- Brazilian prosecutor filed crim...
#
#      Titlebased  Textbased    company_in_title  \
# 0           1.0        1.0     ['J.P. Morgan']
# 1           1.0        1.0          ['Google']
# 2           1.0        1.0          ['Google']
# 3           1.0        1.0            ['BofA']
# 4           1.0        1.0         ['Chevron']
# ..          ...        ...                 ...
# 595         1.0        1.0            ['Citi']
# 596         1.0        NaN  ['General Motors']
# 597         1.0        NaN          ['Oracle']
# 598         1.0        1.0           ['Apple']
# 599         1.0        1.0         ['Chevron']
#
#                                        company_in_text scandal_in_title  \
# 0    ['Chase', 'Fannie Mae', 'Freddie Mac', 'Wells ...   ['settlement']
# 1                              ['Google', 'Microsoft']    ['antitrust']
# 2    ['Microsoft', 'Apple', 'Goldman', 'Expedia', '...    ['antitrust']
# 3    ['Merrill Lynch', 'BofA', 'Countrywide Financi...      ['lawsuit']
# 4                                          ['Chevron']      ['bribe__']
# ..                                                 ...              ...
# 595  ['Goldman', 'Citi', 'Merrill Lynch', 'Goldman'...   ['settlement']
# 596                                                NaN     ['extort__']
# 597        ['Oracle', 'Microsoft', 'Sun Microsystems']      ['ghost__']
# 598  ['Barnes & Noble', 'Apple', 'CBS', 'Amazon', '...     ['collus__']
# 599                                        ['Chevron']       ['leak__']
#
#                             scandal_in_text  GPT scandals_manual scandals_all  \
# 0        ['lawsuit', 'settlement', 'fraud']  NaN               Y          NaN
# 1      ['lawsuit', 'antitrust', 'violat__']  NaN               Y          NaN
# 2    ['misus__', 'antitrust', 'settlement']  NaN               Y          NaN
# 3               ['settlement', 'litigat__']  NaN               Y          NaN
# 4                              ['briber__']  NaN               Y          NaN
# ..                                      ...  ...             ...          ...
# 595     ['penalt__', 'settlement', 'fraud']  NaN               Y          NaN
# 596                                     NaN  NaN               Y          NaN
# 597                                     NaN  NaN               Y          NaN
# 598              ['violat__', 'settlement']  NaN               Y          NaN
# 599                              ['leak__']  NaN               Y          NaN
#
#                                                   text label
# 0     Global Finance: J.P. Morgan Nears SEC Settlement     Y
# 1     Corporate News: Behind Google's Antitrust Escape     Y
# 2    Google Dodges Antitrust Hit --- FTC Extracts L...     Y
# 3    BofA Takes New Crisis-Era Hit --- Shareholder ...     Y
# 4    Oil Giants Launch Bribe Probes --- Eni, Chevro...     Y
# ..                                                 ...   ...
# 595     Judge to Citi and SEC: Explain Your Settlement     Y
# 596    Woman Charged With Extorting Yankees GM Cashman     Y
# 597                 Oracle's Ghost of Christmas Future     Y
# 598  U.S. Warns Apple, Publishers --- Justice Depar...     Y
# 599  Corporate News: Brazil Charges Chevron --- Oil...     Y
#
# [600 rows x 15 columns]

# %%
merged_df.to_csv("ScandalsRevised1.csv")

# %%
import pandas as pd
import numpy as np
import nltk
import gensim
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from imblearn.over_sampling import SMOTE
from gensim.models import KeyedVectors
import seaborn as sns
import matplotlib.pyplot as plt

# Download NLTK resources
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/giuseppebaccaro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/giuseppebaccaro/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load pre-trained Word2Vec model (Google's pre-trained model)
word2vec_path = '../GoogleNews-vectors-negative300.bin.gz'
word2vec = KeyedVectors.load_word2vec_format(word2vec_path, binary=True)

# %%
# Custom transformer to preprocess text data and convert to average Word2Vec vectors
class Word2VecTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, word2vec, vector_size=300):
        self.word2vec = word2vec
        self.vector_size = vector_size
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('english'))

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        processed_docs = X.apply(self._preprocess)
        return np.array([
            np.mean([self.word2vec[word] for word in words if word in self.word2vec]
                    or [np.zeros(self.vector_size)], axis=0)
            for words in processed_docs.str.split()
        ])

    def _preprocess(self, doc):
        doc = re.sub('[^a-zA-Z]', ' ', doc)
        doc = doc.lower().split()
        doc = [self.lemmatizer.lemmatize(word) for word in doc if word not in self.stop_words]
        return ' '.join(doc)

# Load the labeled dataset
labeled_df = pd.read_csv('ScandalsRevised1.csv')

# Preprocess the dataset
labeled_df = labeled_df[["GOID", "text", "label"]]
labeled_df['label'] = labeled_df['label'].fillna('N')

X = labeled_df['text']
y = labeled_df['label']

# Ensure all values in X are strings
X = X.astype(str)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.31, random_state=42)

# Transform the text data to Word2Vec vectors
word2vec_transformer = Word2VecTransformer(word2vec)
X_train_vectors = word2vec_transformer.transform(X_train)
X_test_vectors = word2vec_transformer.transform(X_test)

# Apply SMOTE to the numerical vectors to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_vectors, y_train)

# Define pipeline for the Logistic Regression classifier
PipeLR = Pipeline([
    ("clf", LogisticRegression(max_iter=1000, class_weight='balanced'))
])

# Train the model on the resampled training data
PipeLR.fit(X_train_resampled, y_train_resampled)

# Make predictions on the test set
PredictLR = PipeLR.predict(X_test_vectors)

# %%
# Print accuracy scores and classification reports
print("LogisticRegression Accuracy:", accuracy_score(y_test, PredictLR))
print("Classification Report for LogisticRegression:")
print(classification_report(y_test, PredictLR))

print("Confusion Matrix for LogisticRegression:")
cm_lr = confusion_matrix(y_test, PredictLR)
print(cm_lr)
# Out:
# LogisticRegression Accuracy: 0.9032258064516129
# Classification Report for LogisticRegression:
#               precision    recall  f1-score   support
#
#            N       0.30      0.78      0.44         9
#            Y       0.99      0.91      0.95       177
#
#     accuracy                           0.90       186
#    macro avg       0.65      0.84      0.69       186
# weighted avg       0.95      0.90      0.92       186
#
# Confusion Matrix for LogisticRegression:
# [[  7   2]
#  [ 16 161]]

# %%
# Plot the confusion matrix for LogisticRegression
plt.figure(figsize=(10,7))
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues', xticklabels=['N', 'Y'], yticklabels=['N', 'Y'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for LogisticRegression')
plt.show()
